# %% [markdown]
# # GBM Testing

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import warnings
from tqdm import tqdm
warnings.filterwarnings("ignore")
os.chdir('../')

# %% [markdown]
# ## GBDT

# %%
np.random.seed(42)
m = 200
X = np.random.rand(m, 1)
y = 4 * (X - 0.5) ** 2
y = y + np.random.randn(m, 1) / 10

def plot_regression(X,y):
    fig, axes = plt.subplots(nrows=1, ncols=2 ,figsize = (14,4))
    axes[0].set_xlabel("$x_1$", fontsize=18)
    axes[0].plot(X, y, "b.")
    return fig, axes

# %%
from Trees.GradientBoost import GradientBoostTree
from  importlib import reload as rl
import Trees.GradientBoost
rl(Trees.DecisionTree)
rl(Trees.GradientBoost)
from Trees.GradientBoost import GradientBoostTree
gbdt = GradientBoostTree(n_estimator=100,learning_rate=0.9,max_depth=5)

# %%
for n_estimator in tqdm(range(1,10)):
    depth = 3
    fig, axes = plot_regression(X,y)
    axe = axes[0].axis()
    x1 = np.linspace(X.min(), X.max(), 500).reshape(-1, 1)
    gbdt = GradientBoostTree(n_estimator=n_estimator, learning_rate=5e-1,max_depth=depth)
    gbdt.fit(X,y)
    axes[0].set_title('n_estimator= {} depth={}'.format(n_estimator,depth))
    axes[1].set_title('error'.format(n_estimator,depth))
    axes[1].axis([0,1,-1,1])
    y_pred = gbdt.predict(x1)
    axes[0].plot(x1, y_pred, "r-", linewidth=1, label=r"$\hat{y}$")
    axes[1].plot(X, (y-gbdt.predict(X).reshape(-1,1)), "r.", linewidth=1, label=r"$\hat{y}$")  
    fig.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.75it/s]
